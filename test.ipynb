# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb

# %%
# %sql SELECT * FROM songplay_table LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [(datetime.datetime(2018, 11, 1, 21, 1, 46, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 5, 52, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 8, 16, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 11, 13, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 17, 33, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 24, 53, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 28, 54, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 42, 0, 796000), '10', 'free', None, None, 9, 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (datetime.datetime(2018, 11, 1, 21, 52, 5, 796000), '26', 'free', None, None, 169, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 55, 25, 796000), '26', 'free', None, None, 169, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 22, 23, 14, 796000), '101', 'free', None, None, 100, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 1, 46, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 5, 52, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 8, 16, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 11, 13, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 17, 33, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 24, 53, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 28, 54, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 42, 0, 796000), '10', 'free', None, None, 9, 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (datetime.datetime(2018, 11, 1, 21, 52, 5, 796000), '26', 'free', None, None, 169, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 55, 25, 796000), '26', 'free', None, None, 169, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 22, 23, 14, 796000), '101', 'free', None, None, 100, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 1, 46, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 5, 52, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 8, 16, 796000), '8', 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"')]

# %%
# %sql SELECT * FROM user_table LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [(8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free')]

# %%
# %sql SELECT * FROM song_table LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179)]

# %%
# %sql SELECT * FROM artist_table LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', nan),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', nan),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', nan),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', nan),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', nan)]

# %%
# %sql SELECT * FROM time_table LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [(21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (22, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (22, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018),
#  (21, 3, 44, 11, 2018)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
